# %% [markdown]
# <a href="https://colab.research.google.com/github/rajesh16pytho/internship_projects_dataanalyst/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-b4636764-b50e-4678-940b-b6eca512c4a1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b4636764-b50e-4678-940b-b6eca512c4a1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
upload = files.upload()
# Out:
#      <input type="file" id="files-2162d43f-138a-48aa-86c4-67b7878d546b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2162d43f-138a-48aa-86c4-67b7878d546b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install pandas numpy matplotlib scikit-learn

# %%
# %run churn_analysis.py
# Out:
#   CustomerID  Age  Gender Region      Plan ContractType  TenureMonths  \
# 0     C00001   56  Female  North  Standard      Monthly            19
# 1     C00002   46    Male  South   Premium      Monthly            38
# 2     C00003   32    Male   East  Standard       Annual             9
# 3     C00004   60  Female  South  Standard       Annual            27
# 4     C00005   25  Female   East   Premium      Monthly            49
#
#    MonthlyCharges  UsageHours  SupportTickets  PaymentDelayDays  \
# 0           56.98         6.1               2                 0
# 1           78.03        34.5               3                 3
# 2           38.96        37.7               8                 0
# 3           46.68        42.4               4                 1
# 4           81.81        38.4               3                 0
#
#    SatisfactionScore  LastLoginDays  DiscountPercent Churn  AnnualRevenue
# 0                4.2             13              0.0    No         683.76
# ...
